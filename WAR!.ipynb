# %%
import random

# %%
# Used to create the deck and have values attibutable to the card

suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

# %%
class Card():    # Creates a card with a suit, rank, and value
    
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]    # Dictionary lookup for existing object
        
    def __str__(self):
        return self.rank + ' of ' +self.suit    # str method to print card

# %%
class Deck():    # Creates a deck with 1 of each of the cards
    
    def __init__(self):    
        self.all_cards = []    # Only need to create a deck once - always the same
        for suit in suits:
            for rank in ranks:
                self.all_cards.append(Card(suit,rank))
                
    def shuffle(self):
        random.shuffle(self.all_cards)    # .shuffle() randomized the Cards in the deck
        
    def deal_one(self):   
        return self.all_cards.pop()     # .pop() returns the card removed from the list
        
    def __str__(self):
        card_string = ''
        for card in self.all_cards:
            card_string += '\n'+card.__str__()    # calls the str method from Card class and concatenates onto the string
        return card_string

# %%
class Player():
    
    def __init__(self,name):
        self.name = name
        self.all_cards = []
        
    def remove_one(self):
        return self.all_cards.pop(0)    # Removes a card from top of deck
    
    def add_cards(self,new_cards):
        if type(new_cards) == type([]):    
            self.all_cards.extend(new_cards)    # if adding a list, use extend
        else:
            self.all_cards.append(new_cards)    # if addist single card, use append
            
    def __str__(self):
        return f'{self.name}: {len(self.all_cards)}'

# %%
player_1 = input('Player 1, enter your name:  ')    # inputs players name for a personal touch
print('Thank you, {}'.format(player_1))
player_2 = input('Player 2, enter you name:  ')    # inputs players name for a personal touch
print('Thank you, {}\n'.format(player_2))

p_1 = Player(player_1)    # establishes Player class
p_2 = Player(player_2)    # establishes Player class

deck = Deck()    # creates the Deck class as deck
deck.shuffle()    # randomized the deck

for c in range(26):    # deals one card 26 times to each Player
    p_1.add_cards(deck.deal_one())
    p_2.add_cards(deck.deal_one())
    

    
game_on = True

round_count = 0

while game_on is True:
    
    round_count += 1
    print(f"Round {round_count}:      Card Count: {p_1} & {p_2}")
    
    if len(p_1.all_cards) == 0:    # Player loses when out of cards
        print(f"\nGame OVER. {player_1} is out of cards.")
        print(f"{player_2} WINS!!!")
        game_on = False    # Game over - p1 loses
        break
    
    if len(p_2.all_cards) == 0:    # Player loses when out of cards
        print(f"\nGame OVER. {player_2} is out of cards.")
        print(f"{player_1} WINS!!!")
        game_on = False    # Game over - p2 loses
        break
              
        # keep playing while both players have cards
        
    p1_table_cards = []   # where p_1 places the cards
    p1_table_cards.append(p_1.remove_one())    # p1 removes from pile & add to table
        
    
    p2_table_cards = []    # where p_2 places the cards
    p2_table_cards.append(p_2.remove_one())    # p2 removes from pile & adds to table
    
    
    at_war = True
    
    while at_war:    
        
        if p1_table_cards[-1].value > p2_table_cards[-1].value:
            print(f"\t\t{p1_table_cards[-1].rank} vs {p2_table_cards[-1].rank}")    # Show the cards compared
            p_1.add_cards(p2_table_cards)    # p1 wins battle and gets cards
            p_1.add_cards(p1_table_cards)
        
            at_war = False
        
        elif p1_table_cards[-1].value < p2_table_cards[-1].value:
            print(f"\t\t{p1_table_cards[-1].rank} vs {p2_table_cards[-1].rank}")    # Show the cards compared
            p_2.add_cards(p1_table_cards)    # p2 wins battle and gets cards
            p_2.add_cards(p2_table_cards)
            
            at_war = False
            
        else:
            print(f"\t\t{p1_table_cards[-1].rank} vs {p2_table_cards[-1].rank}")    # Show the cards compared
            print("Let's go to WAR!")
            
            if len(p_1.all_cards) < 5:    # Player needs at least 5 cards to play
                print(f"\n{player_1} is unable to wage war.")
                print(f"{player_2} WINS!")
                
                game_on = False
                break
                
            elif len(p_2.all_cards) < 5:    # Player needs at least 5 cards to play
                print(f"\n{player_2} is unable to wage war.")
                print(f"{player_1} WINS!")
                
                game_on = False
                break
                
            else:
                for c in range(5):    # In war, 5 cards from each p are added to the table - the last card is compared
                    p1_table_cards.append(p_1.remove_one())
                    p2_table_cards.append(p_2.remove_one())
# Out:
# Player 1, enter your name:  Santi
# Thank you, Santi
# Player 2, enter you name:  Gabriel
# Thank you, Gabriel
#
# Round 1:      Card Count: Santi: 26 & Gabriel: 26
# 		King vs Nine
# Round 2:      Card Count: Santi: 27 & Gabriel: 25
# 		Eight vs Seven
# Round 3:      Card Count: Santi: 28 & Gabriel: 24
# 		Jack vs Four
# Round 4:      Card Count: Santi: 29 & Gabriel: 23
# 		Three vs Ten
# Round 5:      Card Count: Santi: 28 & Gabriel: 24
# 		Queen vs Ace
# Round 6:      Card Count: Santi: 27 & Gabriel: 25
# 		Five vs Queen
# Round 7:      Card Count: Santi: 26 & Gabriel: 26
# 		Two vs Ten
# Round 8:      Card Count: Santi: 25 & Gabriel: 27
# 		Jack vs Six
# Round 9:      Card Count: Santi: 26 & Gabriel: 26
# 		King vs King
# Let's go to WAR!
# 		Ace vs Six
# Round 10:      Card Count: Santi: 32 & Gabriel: 20
# 		Nine vs Eight
# Round 11:      Card Count: Santi: 33 & Gabriel: 19
# 		Five vs Two
# Round 12:      Card Count: Santi: 34 & Gabriel: 18
# 		Nine vs Eight
# Round 13:      Card Count: Santi: 35 & Gabriel: 17
# 		Ten vs Four
# Round 14:      Card Count: Santi: 36 & Gabriel: 16
# 		Two vs Two
# Let's go to WAR!
# 		Seven vs Jack
# Round 15:      Card Count: Santi: 30 & Gabriel: 22
# 		Seven vs Five
# Round 16:      Card Count: Santi: 31 & Gabriel: 21
# 		Five vs Three
# Round 17:      Card Count: Santi: 32 & Gabriel: 20
# 		Nine vs Three
# Round 18:      Card Count: Santi: 33 & Gabriel: 19
# 		King vs Ten
# Round 19:      Card Count: Santi: 34 & Gabriel: 18
# 		Seven vs Queen
# Round 20:      Card Count: Santi: 33 & Gabriel: 19
# 		Eight vs Ace
# Round 21:      Card Count: Santi: 32 & Gabriel: 20
# 		Four vs Five
# Round 22:      Card Count: Santi: 31 & Gabriel: 21
# 		Jack vs Queen
# Round 23:      Card Count: Santi: 30 & Gabriel: 22
# 		Six vs Two
# Round 24:      Card Count: Santi: 31 & Gabriel: 21
# 		Jack vs Ten
# Round 25:      Card Count: Santi: 32 & Gabriel: 20
# 		King vs Two
# Round 26:      Card Count: Santi: 33 & Gabriel: 19
# 		Six vs Six
# Let's go to WAR!
# 		King vs Two
# Round 27:      Card Count: Santi: 39 & Gabriel: 13
# 		Ace vs Queen
# Round 28:      Card Count: Santi: 40 & Gabriel: 12
# 		Eight vs Four
# Round 29:      Card Count: Santi: 41 & Gabriel: 11
# 		Seven vs Jack
# Round 30:      Card Count: Santi: 40 & Gabriel: 12
# 		Four vs Ace
# Round 31:      Card Count: Santi: 39 & Gabriel: 13
# 		Ace vs Jack
# Round 32:      Card Count: Santi: 40 & Gabriel: 12
# 		Eight vs Seven
# Round 33:      Card Count: Santi: 41 & Gabriel: 11
# 		Nine vs Queen
# Round 34:      Card Count: Santi: 40 & Gabriel: 12
# 		Two vs Eight
# Round 35:      Card Count: Santi: 39 & Gabriel: 13
# 		Five vs Ace
# Round 36:      Card Count: Santi: 38 & Gabriel: 14
# 		Eight vs Four
# Round 37:      Card Count: Santi: 39 & Gabriel: 13
# 		Nine vs Five
# Round 38:      Card Count: Santi: 40 & Gabriel: 12
# 		Four vs Jack
# Round 39:      Card Count: Santi: 39 & Gabriel: 13
# 		Ten vs Queen
# Round 40:      Card Count: Santi: 38 & Gabriel: 14
# 		Five vs Seven
# Round 41:      Card Count: Santi: 37 & Gabriel: 15
# 		Seven vs Jack
# Round 42:      Card Count: Santi: 36 & Gabriel: 16
# 		Three vs Four
# Round 43:      Card Count: Santi: 35 & Gabriel: 17
# 		Five vs Ace
# Round 44:      Card Count: Santi: 34 & Gabriel: 18
# 		Three vs Nine
# Round 45:      Card Count: Santi: 33 & Gabriel: 19
# 		Nine vs Queen
# Round 46:      Card Count: Santi: 32 & Gabriel: 20
# 		Ten vs Two
# Round 47:      Card Count: Santi: 33 & Gabriel: 19
# 		King vs Eight
# Round 48:      Card Count: Santi: 34 & Gabriel: 18
# 		Two vs Five
# Round 49:      Card Count: Santi: 33 & Gabriel: 19
# 		Six vs Ace
# Round 50:      Card Count: Santi: 32 & Gabriel: 20
# 		Ten vs Four
# Round 51:      Card Count: Santi: 33 & Gabriel: 19
# 		Jack vs Jack
# Let's go to WAR!
# 		Three vs Seven
# Round 52:      Card Count: Santi: 27 & Gabriel: 25
# 		Three vs Jack
# Round 53:      Card Count: Santi: 26 & Gabriel: 26
# 		Seven vs Three
# Round 54:      Card Count: Santi: 27 & Gabriel: 25
# 		Two vs Four
# Round 55:      Card Count: Santi: 26 & Gabriel: 26
# 		Six vs Five
# Round 56:      Card Count: Santi: 27 & Gabriel: 25
# 		Nine vs Ace
# Round 57:      Card Count: Santi: 26 & Gabriel: 26
# 		Queen vs Three
# Round 58:      Card Count: Santi: 27 & Gabriel: 25
# 		Ten vs Nine
# Round 59:      Card Count: Santi: 28 & Gabriel: 24
# 		Six vs Nine
# Round 60:      Card Count: Santi: 27 & Gabriel: 25
# 		King vs Queen
# Round 61:      Card Count: Santi: 28 & Gabriel: 24
# 		Queen vs Two
# Round 62:      Card Count: Santi: 29 & Gabriel: 23
# 		Ace vs Five
# Round 63:      Card Count: Santi: 30 & Gabriel: 22
# 		Four vs Six
# Round 64:      Card Count: Santi: 29 & Gabriel: 23
# 		Eight vs Ace
# Round 65:      Card Count: Santi: 28 & Gabriel: 24
# 		Jack vs Jack
# Let's go to WAR!
# 		Eight vs Three
# Round 66:      Card Count: Santi: 34 & Gabriel: 18
# 		Five vs Jack
# Round 67:      Card Count: Santi: 33 & Gabriel: 19
# 		Nine vs Ten
# Round 68:      Card Count: Santi: 32 & Gabriel: 20
# 		Two vs Queen
# Round 69:      Card Count: Santi: 31 & Gabriel: 21
# 		Ten vs Five
# Round 70:      Card Count: Santi: 32 & Gabriel: 20
# 		Eight vs Seven
# Round 71:      Card Count: Santi: 33 & Gabriel: 19
# 		King vs Seven
# Round 72:      Card Count: Santi: 34 & Gabriel: 18
# 		Four vs Three
# Round 73:      Card Count: Santi: 35 & Gabriel: 17
# 		Ten vs Jack
# Round 74:      Card Count: Santi: 34 & Gabriel: 18
# 		Three vs Two
# Round 75:      Card Count: Santi: 35 & Gabriel: 17
# 		Seven vs Four
# Round 76:      Card Count: Santi: 36 & Gabriel: 16
# 		Five vs Nine
# Round 77:      Card Count: Santi: 35 & Gabriel: 17
# 		Six vs Ace
# Round 78:      Card Count: Santi: 34 & Gabriel: 18
# 		Three vs Six
# Round 79:      Card Count: Santi: 33 & Gabriel: 19
# 		Queen vs Nine
# Round 80:      Card Count: Santi: 34 & Gabriel: 18
# 		Nine vs Four
# Round 81:      Card Count: Santi: 35 & Gabriel: 17
# 		Ten vs Six
# Round 82:      Card Count: Santi: 36 & Gabriel: 16
# 		Queen vs Eight
# Round 83:      Card Count: Santi: 37 & Gabriel: 15
# 		King vs Ace
# Round 84:      Card Count: Santi: 36 & Gabriel: 16
# 		Two vs Five
# Round 85:      Card Count: Santi: 35 & Gabriel: 17
# 		Queen vs Jack
# Round 86:      Card Count: Santi: 36 & Gabriel: 16
# 		Five vs Nine
# Round 87:      Card Count: Santi: 35 & Gabriel: 17
# 		Ace vs Ten
# Round 88:      Card Count: Santi: 36 & Gabriel: 16
# 		Jack vs Two
# Round 89:      Card Count: Santi: 37 & Gabriel: 15
# 		Two vs Queen
# Round 90:      Card Count: Santi: 36 & Gabriel: 16
# 		King vs Ten
# Round 91:      Card Count: Santi: 37 & Gabriel: 15
# 		Six vs Jack
# Round 92:      Card Count: Santi: 36 & Gabriel: 16
# 		King vs Five
# Round 93:      Card Count: Santi: 37 & Gabriel: 15
# 		Three vs Nine
# Round 94:      Card Count: Santi: 36 & Gabriel: 16
# 		Jack vs Six
# Round 95:      Card Count: Santi: 37 & Gabriel: 15
# 		Ace vs Ace
# Let's go to WAR!
# 		Five vs Two
# Round 96:      Card Count: Santi: 43 & Gabriel: 9
# 		Ten vs Five
# Round 97:      Card Count: Santi: 44 & Gabriel: 8
# 		Seven vs Five
# Round 98:      Card Count: Santi: 45 & Gabriel: 7
# 		Eight vs Nine
# Round 99:      Card Count: Santi: 44 & Gabriel: 8
# 		Seven vs Two
# Round 100:      Card Count: Santi: 45 & Gabriel: 7
# 		King vs Queen
# Round 101:      Card Count: Santi: 46 & Gabriel: 6
# 		Three vs Six
# Round 102:      Card Count: Santi: 45 & Gabriel: 7
# 		Four vs Jack
# Round 103:      Card Count: Santi: 44 & Gabriel: 8
# 		Two vs Three
# Round 104:      Card Count: Santi: 43 & Gabriel: 9
# 		Three vs Nine
# Round 105:      Card Count: Santi: 42 & Gabriel: 10
# 		Four vs Eight
# Round 106:      Card Count: Santi: 41 & Gabriel: 11
# 		Seven vs Nine
# Round 107:      Card Count: Santi: 40 & Gabriel: 12
# 		Nine vs Three
# Round 108:      Card Count: Santi: 41 & Gabriel: 11
# 		Queen vs Six
# Round 109:      Card Count: Santi: 42 & Gabriel: 10
# 		Four vs Four
# Let's go to WAR!
# 		Queen vs Nine
# Round 110:      Card Count: Santi: 48 & Gabriel: 4
# 		Jack vs Four
# Round 111:      Card Count: Santi: 49 & Gabriel: 3
# 		Queen vs Eight
# Round 112:      Card Count: Santi: 50 & Gabriel: 2
# 		Ten vs Seven
# Round 113:      Card Count: Santi: 51 & Gabriel: 1
# 		Ace vs Nine
# Round 114:      Card Count: Santi: 52 & Gabriel: 0
#
# Game OVER. Gabriel is out of cards.
# Santi WINS!!!
